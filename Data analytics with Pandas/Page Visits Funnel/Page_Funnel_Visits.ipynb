# %%
import pandas as pd

# %% [markdown]
# Import all the files

# %%
visits = pd.read_csv('visits.csv',
                     parse_dates=[1])
cart = pd.read_csv('cart.csv',
                   parse_dates=[1])
                   
checkout = pd.read_csv('checkout.csv',
                       parse_dates=[1])
purchase = pd.read_csv('purchase.csv',
                       parse_dates=[1])

# %% [markdown]
# Step 1: Inspect the DataFrames using `print` and `head`

# %%
print(visits.head(5))
print(cart.head(5))
print(checkout.head(5))
print(purchase.head(5))
# Out:
#                                 user_id          visit_time
# 0  943647ef-3682-4750-a2e1-918ba6f16188 2017-04-07 15:14:00
# 1  0c3a3dd0-fb64-4eac-bf84-ba069ce409f2 2017-01-26 14:24:00
# 2  6e0b2d60-4027-4d9a-babd-0e7d40859fb1 2017-08-20 08:23:00
# 3  6879527e-c5a6-4d14-b2da-50b85212b0ab 2017-11-04 18:15:00
# 4  a84327ff-5daa-4ba1-b789-d5b4caf81e96 2017-02-27 11:25:00
#                                 user_id           cart_time
# 0  2be90e7c-9cca-44e0-bcc5-124b945ff168 2017-11-07 20:45:00
# 1  4397f73f-1da3-4ab3-91af-762792e25973 2017-05-27 01:35:00
# 2  a9db3d4b-0a0a-4398-a55a-ebb2c7adf663 2017-03-04 10:38:00
# 3  b594862a-36c5-47d5-b818-6e9512b939b3 2017-09-27 08:22:00
# 4  a68a16e2-94f0-4ce8-8ce3-784af0bbb974 2017-07-26 15:48:00
#                                 user_id       checkout_time
# 0  d33bdc47-4afa-45bc-b4e4-dbe948e34c0d 2017-06-25 09:29:00
# 1  4ac186f0-9954-4fea-8a27-c081e428e34e 2017-04-07 20:11:00
# 2  3c9c78a7-124a-4b77-8d2e-e1926e011e7d 2017-07-13 11:38:00
# ...

# %% [markdown]
# Step 2: Left merging visits and cart

# %%
visits_cart = pd.merge(visits, cart, how='left')
visits_cart
# Out:
#                                    user_id          visit_time  \
# 0     943647ef-3682-4750-a2e1-918ba6f16188 2017-04-07 15:14:00
# 1     0c3a3dd0-fb64-4eac-bf84-ba069ce409f2 2017-01-26 14:24:00
# 2     6e0b2d60-4027-4d9a-babd-0e7d40859fb1 2017-08-20 08:23:00
# 3     6879527e-c5a6-4d14-b2da-50b85212b0ab 2017-11-04 18:15:00
# 4     a84327ff-5daa-4ba1-b789-d5b4caf81e96 2017-02-27 11:25:00
# ...                                    ...                 ...
# 1995  33913ac2-03da-45ae-8fc3-fea39df827c6 2017-03-25 03:29:00
# 1996  4f850132-b99d-4623-80e6-6e61d003577e 2017-01-08 09:57:00
# 1997  f0830b9b-1f5c-4e74-b63d-3f847cc6ce70 2017-09-07 12:56:00
# 1998  b01bffa7-63ba-4cd3-9d93-eb1477c23831 2017-07-20 04:37:00
# 1999  0336ca81-8d68-443f-9248-ac0b8ad147d5 2017-11-15 10:11:00
#
#                cart_time
# 0                    NaT
# 1    2017-01-26 14:44:00
# 2    2017-08-20 08:31:00
# 3                    NaT
# 4                    NaT
# ...                  ...
# ...

# %% [markdown]
# Step 3: How long is `visits_cart`?

# %%
len(visits_cart)
# Out:
# 2000

# %% [markdown]
# Step 4: How many timestamps are null for `cart_time`?

# %%
nullCartTimes = visits_cart[visits_cart['cart_time'].isnull()]
len(nullCartTimes)
# Out:
# 1652

# %% [markdown]
# Step 5: What percentage only visited?

# %%
perc_only_visited = (len(nullCartTimes)/len(visits_cart))*100
perc_only_visited
# Out:
# 82.6

# %% [markdown]
# Step 6: What percentage placed a t-shirt in their cart but did not checkout?

# %%
cart_noCheck = pd.merge(cart, checkout, how='left')
null_cart = cart_noCheck[cart_noCheck['checkout_time'].isnull()]
perc_checkOut = (len(null_cart)/len(cart_noCheck))*100
perc_checkOut
# Out:
# 35.05747126436782

# %% [markdown]
# Step 7: Merge it all together

# %%
all_data = visits.merge(cart, how='left').merge(checkout, how='left').merge(purchase , how='left')
all_data
# Out:
#                                    user_id          visit_time  \
# 0     943647ef-3682-4750-a2e1-918ba6f16188 2017-04-07 15:14:00
# 1     0c3a3dd0-fb64-4eac-bf84-ba069ce409f2 2017-01-26 14:24:00
# 2     6e0b2d60-4027-4d9a-babd-0e7d40859fb1 2017-08-20 08:23:00
# 3     6879527e-c5a6-4d14-b2da-50b85212b0ab 2017-11-04 18:15:00
# 4     a84327ff-5daa-4ba1-b789-d5b4caf81e96 2017-02-27 11:25:00
# ...                                    ...                 ...
# 2103  33913ac2-03da-45ae-8fc3-fea39df827c6 2017-03-25 03:29:00
# 2104  4f850132-b99d-4623-80e6-6e61d003577e 2017-01-08 09:57:00
# 2105  f0830b9b-1f5c-4e74-b63d-3f847cc6ce70 2017-09-07 12:56:00
# 2106  b01bffa7-63ba-4cd3-9d93-eb1477c23831 2017-07-20 04:37:00
# 2107  0336ca81-8d68-443f-9248-ac0b8ad147d5 2017-11-15 10:11:00
#
#                cart_time       checkout_time       purchase_time
# 0                    NaT                 NaT                 NaT
# 1    2017-01-26 14:44:00 2017-01-26 14:54:00 2017-01-26 15:08:00
# ...

# %% [markdown]
# Step 8: % of users who got to checkout but did not purchase

# %%
no_checkout_people = all_data[all_data['checkout_time'].isnull()]
checkout_people = len(all_data) - len(no_checkout_people)
no_purchase_people = all_data[all_data['purchase_time'].isnull()]
checkout_no_purchase = len(no_purchase_people) - len(no_checkout_people)
perc_checkNoPur = (1-(checkout_no_purchase / checkout_people))*100
perc_checkNoPur
# Out:
# 75.44910179640718

# %% [markdown]
# Step 9: check each part of the funnel, let's print all 3 of them again

# %%
print(perc_only_visited)
print(perc_checkOut)
print(perc_checkNoPur)
# Out:
# 82.6
# 35.05747126436782
# 75.44910179640718

# %% [markdown]
# *The weakest part of the funnel is clearly getting a person who visited the site to add a tshirt to their cart. Once they've added a t-shirt to their cart it is fairly likely they end up purchasing it. A suggestion could be to make the add-to-cart button more prominent on the front page.*
#
#
# Step 10: adding new column

# %%
all_data['avarage_time'] = all_data['purchase_time'] - all_data['visit_time']
all_data
# Out:
#                                    user_id          visit_time  \
# 0     943647ef-3682-4750-a2e1-918ba6f16188 2017-04-07 15:14:00
# 1     0c3a3dd0-fb64-4eac-bf84-ba069ce409f2 2017-01-26 14:24:00
# 2     6e0b2d60-4027-4d9a-babd-0e7d40859fb1 2017-08-20 08:23:00
# 3     6879527e-c5a6-4d14-b2da-50b85212b0ab 2017-11-04 18:15:00
# 4     a84327ff-5daa-4ba1-b789-d5b4caf81e96 2017-02-27 11:25:00
# ...                                    ...                 ...
# 2103  33913ac2-03da-45ae-8fc3-fea39df827c6 2017-03-25 03:29:00
# 2104  4f850132-b99d-4623-80e6-6e61d003577e 2017-01-08 09:57:00
# 2105  f0830b9b-1f5c-4e74-b63d-3f847cc6ce70 2017-09-07 12:56:00
# 2106  b01bffa7-63ba-4cd3-9d93-eb1477c23831 2017-07-20 04:37:00
# 2107  0336ca81-8d68-443f-9248-ac0b8ad147d5 2017-11-15 10:11:00
#
#                cart_time       checkout_time       purchase_time  \
# 0                    NaT                 NaT                 NaT
# 1    2017-01-26 14:44:00 2017-01-26 14:54:00 2017-01-26 15:08:00
# ...

# %% [markdown]
# Step 11: examine the results

# %%
all_data['avarage_time']
# Out:
# 0                  NaT
# 1      0 days 00:44:00
# 2                  NaT
# 3                  NaT
# 4                  NaT
#              ...
# 2103               NaT
# 2104               NaT
# 2105               NaT
# 2106               NaT
# 2107               NaT
# Name: avarage_time, Length: 2108, dtype: timedelta64[ns]

# %% [markdown]
# Step 12: average time to purchase

# %%
avarageTime_to_purchase = all_data['avarage_time'].mean()
avarageTime_to_purchase
# Out:
# Timedelta('0 days 00:43:12.380952380')
